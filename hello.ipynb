# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,2,4,16])
plt.xlabel("xaxis")
plt.ylabel("y axis")
plt.show()

# %%
import matplotlib.pyplot as plt

x1=[1,2,3,4,5]
y1=[1,4,9,16,25]
x2=[10,20,30,40]
y2=[20,40,60,80]
lines=plt.plot(x1,y1,x2,y2)
plt.grid()
plt.show()

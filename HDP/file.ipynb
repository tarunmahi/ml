# %%
import pandas as pd
df=pd.read_csv("csv_result-EQ.csv")
df.head()
# Out:
#    id  ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0   1                             3   0.002547    0.002555
# 1   2                            37   0.008643    0.004756
# 2   3                             3   0.001479    0.009143
# 3   4                            10   0.005642    0.005395
# 4   5                             1   0.001350    0.000000
#
#    numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                  4                           0.00
# 1                                 71                           0.00
# 2                                  5                           1.01
# 3                                 38                           0.00
# 4                                  1                           1.01
#
#    WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                     3.04     0.393707                    0.003049
# ...

# %%
cnt=0
visited=[]
for i in range(0,len(df['class'])):
    if df['class'][i] not in visited:
        visited.append(df['class'][i])
        cnt+=1

# %%
count=0
clean=0
for i in range(0,len(df['class'])):
    if df['class'][i]=="buggy":
        count+=1
    else:
        clean+=1
        
print(count)
print(clean)
df.info()
# Out:
# 129
# 195
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 63 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   324 non-null    int64
#  1   ck_oo_numberOfPrivateMethods         324 non-null    int64
#  2   LDHH_lcom                            324 non-null    float64
#  3   LDHH_fanIn                           324 non-null    float64
#  4   numberOfNonTrivialBugsFoundUntil:    324 non-null    int64
#  5   WCHU_numberOfPublicAttributes        324 non-null    float64
#  6   WCHU_numberOfAttributes              324 non-null    float64
#  7   CvsWEntropy                          324 non-null    float64
#  8   LDHH_numberOfPublicMethods           324 non-null    float64
#  9   WCHU_fanIn                           324 non-null    float64
#  10  LDHH_numberOfPrivateAttributes       324 non-null    float64
# ...

# %%
print("No.of.unique values :",
      cnt)
  
print("unique values :",
      visited)
# Out:
# No.of.unique values : 2
# unique values : ['buggy', 'clean']
